# %% [markdown]
# Prepare input files.
#
# The ailgnment has been produced using Reprophylo (see notebook). We'll just cleanup the sequence headers and create a local copy.

# %%
# !cat ../fetch_clean_align_tree/trimmed_mammal_align_ALL.phy | sed 's/_f[0-9] / /' > alignment.phy

# %% [markdown]
# The tax file has been generated from a Genbank file using this notebook.

# %%
# !head tax_for_SATIVA.tax
# Out:
# EF027265.1	Eukaryota;Chordata;Mammalia;Rodentia;Cricetidae;Microtus;Microtus arvalis
# KP702285.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries
# AY879429.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries
# AY879349.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries
# EF056451.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries
# EF056393.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries
# EF056448.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries
# EF056453.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries
# EF056455.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries
# AJ000846.1	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries

# %% [markdown]
# Let's now run SATIVA.

# %%
# !./sativa/sativa.py -s alignment.phy -t tax_for_SATIVA.tax -x zoo -n 12S -o ./ -T 5 -v
# Out:
# SATIVA v0.9-55-g0cbb090, released on 2016-06-28. Last version: https://github.com/amkozlov/sativa
# By A.Kozlov and J.Zhang, the Exelixis Lab. Based on RAxML 8.2.3 by A.Stamatakis.
#
# SATIVA was called as follows:
#
# ./sativa/sativa.py -s alignment.phy -t tax_for_SATIVA.tax -x zoo -n 12S -o ./ -T 5 -v
#
# Mislabels search is running with the following parameters:
#  Alignment:                        alignment.phy
#  Taxonomy:                         tax_for_SATIVA.tax
#  Output directory:                 /home/working/Reference_Alignment/Mammals/SATIVA
#  Job name / output files prefix:   12S
#  Model of rate heterogeneity:      AUTO
#  Confidence cut-off:               0.000000
#  Number of threads:                5
#
# *** STEP 1: Building the reference tree using provided alignment and taxonomic annotations ***
#
# => Loading taxonomy from file: tax_for_SATIVA.tax ...
#
# ==> Loading reference alignment from file: alignment.phy ...
#
# Guessing input format: not fasta
# Guessing input format: not phylip_relaxed
# ===> Validating taxonomy and alignment ...
#
# NOTE: Following sequences are identical: AY337520.1, AY337538.1, AY337540.1
# NOTE: Following sequences are identical: EF056406.1, EF056401.1
# NOTE: Following sequences are identical: DQ191149.1, DQ153244.1, DQ191145.1
# NOTE: Following sequences are identical: KC776716.1, KC776696.1
# NOTE: Following sequences are identical: KT757763.1, KT757751.1, KT757753.1, JQ340102.1, KT368731.1, KT757740.1, KT985984.1, JQ340127.1, JQ340108.1, KT757757.1, KT998647.1, HQ439467.1, HQ439445.1, HQ439444.1, AP013089.1, JQ340093.1, KT757744.1, KT757748.1, HQ439485.1, JQ340145.1, AP013078.1, JQ340098.1, HQ439493.1, KT757750.1, HQ439446.1, AP013091.1, HQ439487.1, JQ340125.1, HQ439449.1, JQ340113.1, FJ718998.1, KT757739.1, AY584828.1, AP013084.1, KC203000.1, JQ340092.1, HQ439453.1, AP013087.1, HQ439460.1, AP013090.1, HQ439458.1, JQ340154.1, KT757743.1, JQ340099.1, HQ439462.1, AP013088.1, JQ340151.1
# NOTE: Following sequences are identical: HQ832482.1, AY184433.1, GU457433.1, HQ191428.1, DQ191150.1
# NOTE: Following sequences are identical: EF373884.1, EF373883.1
# NOTE: Following sequences are identical: AJ972680.1, KJ681480.1, KJ681481.1
# NOTE: Following sequences are identical: M10217.1, Y10943.1
# NOTE: Following sequences are identical: KU290497.1, KU290618.1
# NOTE: Following sequences are identical: JX088676.1, JX088680.1
# NOTE: Following sequences are identical: AY962029.1, AY962023.1
# NOTE: Following sequences are identical: AF527537.1, M35877.1, EF035447.1
# NOTE: Following sequences are identical: FR691688.1, AJ389542.1
# NOTE: Following sequences are identical: JF342844.1, KU291066.1, FJ817364.1, JF342890.1, KJ637115.1, JF342861.1, EU408260.1, EU789769.1, AY656739.1
# NOTE: Following sequences are identical: KT368739.1, AB859014.1, AP013080.1, HQ439443.1, KT757761.1, KT757764.1, KC202960.1, EF597512.1
# NOTE: Following sequences are identical: HM236183.1, HM236182.1, HM236178.1
# NOTE: Following sequences are identical: KM892823.1, KM892833.1, KM892832.1
# NOTE: Following sequences are identical: KM520138.1, KJ737423.1, KJ737418.1, AY243484.1, KJ746664.1, KC493609.1, JN601070.1, JN601075.1, KC493610.1, KM998967.1, KJ746663.1
# NOTE: Following sequences are identical: EF362717.1, EF362708.1
# NOTE: Following sequences are identical: KM892817.1, KM892812.1, KM892809.1
# NOTE: Following sequences are identical: AY879419.1, AY879380.1, JN415745.1, EF056418.1, GU350285.1, EF056425.1, DQ852152.1, EF056449.1, JN415734.1, JQ286189.1, EF056459.1, JN415726.1, JN415731.1, JN415737.1, DQ852163.1, GU350339.1, AY879347.1, GU350392.1, AY879457.1, JQ286225.1, JQ286239.1
# NOTE: Following sequences are identical: EF122793.1, JN860636.1
# NOTE: Following sequences are identical: KP223728.1, KM520132.1, KM520142.1, KM520133.1, DQ268530.1, KM520143.1, AF034253.1, KM520135.1, AF486858.1, FJ236992.1, GQ338938.1, AY574046.1, EU333163.1, AY243485.1, AP003428.1, JN601072.1, AF304203.1, KP294522.1, KT965278.1, DQ334861.1, AF486856.1, EF545586.1, DQ207755.1, DQ444705.1, EF545571.1, EF545568.1, EF545588.1, EF545567.1, DQ334860.1, DQ207753.1, KJ746665.1, AY243483.1, KP681245.1, AF304202.1, KM044240.1, AF486870.1, KC493612.1, DQ207754.1, KP681242.1, KP681243.1, AY574047.1, KM520134.1, KM520140.1, KM520137.1, KM520141.1, KM520136.1, KM520144.1, KM520145.1
# NOTE: Following sequences are identical: KP942534.1, KP942529.1, KP942563.1, KP942570.1, KP942548.1, KP942530.1, GU174596.1, KP942543.1, KP942537.1, KP942531.1
# NOTE: Following sequences are identical: EU408291.1, KM061533.1
# NOTE: Following sequences are identical: KF163077.1, KF163062.1, AY676863.1, JN817339.1, KJ709685.1, AB074962.1, AF492351.1, AY676871.1, AY676858.1, JN817317.1, JN817309.1
# NOTE: Following sequences are identical: KM016851.1, KR180298.1, GU187153.1, HQ405755.1, GU187154.1
# NOTE: Following sequences are identical: KC747665.1, KP273591.1
# NOTE: Following sequences are identical: KM892826.1, KM892827.1, KM892821.1
# NOTE: Following sequences are identical: KM488625.1, HM106322.1
# NOTE: Following sequences are identical: KC993007.1, KC993004.1
# NOTE: Following sequences are identical: KT261430.1, KT372134.1
# NOTE: Following sequences are identical: X84384.1, AY012112.1
# NOTE: Following sequences are identical: KC776706.1, KC776705.1, KC776709.1
# NOTE: Following sequences are identical: KC572709.1, X61145.1
# NOTE: Following sequences are identical: AJ885205.1, AJ885206.1
# NOTE: Following sequences are identical: HQ529663.1, HQ529670.1
# NOTE: Following sequences are identical: HM026002.1, HM026052.1, HM026045.1, HM025990.1, HM026009.1, HM026024.1, HM026055.1
# NOTE: Following sequences are identical: AJ554054.1, AP006468.1
# NOTE: Following sequences are identical: AF520669.1, AY012123.1
# NOTE: Following sequences are identical: EF362643.1, EF362639.1
# NOTE: Following sequences are identical: KP981378.1, KP702285.1, AF010406.1, KF977847.1
# NOTE: Following sequences are identical: JN695757.1, KP234022.1
# NOTE: Following sequences are identical: KP172593.1, AY184430.1, AY184431.1, DQ191148.1, DQ191146.1
# NOTE: Following sequences are identical: HM026012.1, HM026014.1
# NOTE: Following sequences are identical: KM091450.1, AB119066.1
# NOTE: Following sequences are identical: FR691686.1, FR691685.1
# NOTE: Following sequences are identical: KM892825.1, KM892840.1, KM892838.1, KM892814.1, KM892837.1, KM892820.1
# NOTE: Following sequences are identical: HQ529681.1, HQ529674.1, HQ529680.1, HQ529673.1
# NOTE: Following sequences are identical: KT757745.1, AP013098.1, HQ439442.1, KT757762.1, KT757760.1, AP013092.1, HQ439455.1, JQ340122.1
# NOTE: Following sequences are identical: AY337528.1, AY337525.1, AY337522.1, AY337531.1, AY337524.1, AY337533.1, AY337523.1, AY337542.1, AY337541.1
# NOTE: Following sequences are identical: AB058610.1, KJ397605.1, KR013248.1
# NOTE: Following sequences are identical: KU891850.1, KT033901.1
# NOTE: Following sequences are identical: EF056433.1, EF056436.1
# NOTE: Following sequences are identical: AY337536.1, AY337543.1, AY337527.1, AY337545.1
# NOTE: Following sequences are identical: DQ191151.1, JN389443.1
# NOTE: Following sequences are identical: AB058611.1, AY745154.1, AY745152.1
# NOTE: Following sequences are identical: KT316285.1, KT316284.1, KT316286.1, KT316287.1
# NOTE: Following sequences are identical: AJ000849.1, AJ000850.1, AJ000848.1
# NOTE: Following sequences are identical: JN632649.1, EU315254.1, M35876.1, JX254914.2, JF802125.1
# NOTE: Following sequences are identical: AY184438.1, KM506758.1
# NOTE: Following sequences are identical: AM181027.1, GU174598.1
# NOTE: Following sequences are identical: JQ621986.1, KF938318.1, HE577850.1, KP998471.1, JQ621985.1, KF938319.1, AY670663.1, HE577847.1, KF938326.1
# NOTE: Following sequences are identical: AJ238588.1, KC993000.1
# NOTE: Following sequences are identical: KM520148.1, EF545585.1
# NOTE: Following sequences are identical: HQ529638.1, HQ529647.1
# NOTE: Following sequences are identical: AP003321.1, FJ610338.1, FJ610339.1, AY235570.1, GU261698.1, GU261674.1, AP003317.1, GU261680.1, GU261678.1, GU261693.1, AB086102.1, KT626848.1, KP211419.1, GU261694.1, AP003318.1
# NOTE: Following sequences are identical: U13083.1, U13100.1
# NOTE: Following sequences are identical: AP006467.1, AY012141.1
# NOTE: Following sequences are identical: EF056393.1, EF056402.1
# NOTE: Following sequences are identical: HM236177.1, HM236174.1
# NOTE: Following sequences are identical: KF317941.1, KF317935.1
# NOTE: Following sequences are identical: HM236176.1, HM236181.1
# NOTE: Following sequences are identical: EF027292.1, EF027290.1
# NOTE: Following sequences are identical: AF263219.1, AF203774.1
# NOTE: Following sequences are identical: KF038159.1, HQ439450.1, JQ340141.1, HQ439448.1, JQ340104.1, EF597514.1, EU939445.3
# NOTE: Following sequences are identical: EU789655.1, EU789654.1, KJ139388.1
# NOTE: Following sequences are identical: KF011917.1, DQ673916.1, KM577634.1
# NOTE: Following sequences are identical: KF781660.1, KF781662.1
# NOTE: Following sequences are identical: KF570389.1, KF570319.1, KU991990.1, EU557093.1, KF570322.1, KT601198.1, KF570371.1, KF570315.1
# NOTE: Following sequences are identical: DQ874614.2, AY057793.1
# NOTE: Following sequences are identical: KR180364.1, GU187173.1, KR180300.1, GU187155.1, GU187156.1
# NOTE: Following sequences are identical: AY184440.1, KJ681489.1
# NOTE: Following sequences are identical: AY121990.1, KJ681482.1
# NOTE: Following sequences are identical: AM181036.1, GU174593.1
# NOTE: Following sequences are identical: AY027823.1, AY027824.1
# NOTE: Following sequences are identical: HQ996541.1, HQ996539.1, HQ996553.1, HQ996533.1
# NOTE: Following sequences are identical: KF918859.1, KM892810.1
# NOTE: Following sequences are identical: HM106318.1, AB119069.1
# NOTE: Following sequences are identical: KM092492.1, GU981053.1
# NOTE: Following sequences are identical: KF570379.1, KF570380.1, AY012142.1
# NOTE: Following sequences are identical: KP342452.1, KT448287.1, AM181037.1
# NOTE: Following sequences are identical: EF056432.1, EF056443.1
# NOTE: Following sequences are identical: GU174597.1, AM181028.1
# NOTE: Following sequences are identical: KT693382.1, Y08515.1
# NOTE: Following sequences are identical: EU789764.1, AY012152.1, DQ480489.1
# NOTE: Following sequences are identical: FJ688100.1, FJ688101.1
# NOTE: Following sequences are identical: AB245426.1, AY121989.1
# NOTE: Following sequences are identical: JN632610.1, KJ681485.1, KJ681486.1, KJ681487.1
# NOTE: Following sequences are identical: KJ192209.1, KJ192210.1, KR059188.1, KR059213.1, KR059159.1, GU229281.1, KR059197.1, GU229280.1, M55541.1, KR059154.1, KM244714.1, KJ789954.1, KR349363.1, KP231536.1
# NOTE: Following sequences are identical: KX512321.1, KM886936.1
# NOTE: Following sequences are identical: AM181032.1, X63726.1
# NOTE: Following sequences are identical: JF342816.1, KF661083.1, EU408288.1, KJ139384.1, DQ480492.1, KU290662.1, KU290520.1, KU290785.1, KU290461.1, KU290793.1, KU290401.1, KU290464.1, EU789673.1, EU789640.1, EU789662.1, AB048590.1, FJ817358.1, DQ480499.1, KU290597.1, JF342832.1, KU290812.1, KU290423.1, KU290428.1, KU290811.1, KU290822.1, KU290815.1, KJ637099.1, JF342836.1, KU291057.1, KU290814.1, EU408300.1, EU789688.1, KU290402.1, KU290404.1, KU290731.1, EU789717.1, KU290642.1, KU290622.1, KU290609.1, AY656749.1, AY656737.1, KU290453.1, EU789744.1, KM061586.1, KU291054.1, EU408262.1, KU290907.1, EU789741.1, KU290668.1, JX088685.1, JX088672.1, EU789663.1, KU290857.1, FJ817359.1, KU290971.1, KU290850.1, KU290620.1, EU789710.1, JF342891.1, EU789686.1, JF342893.1, JF342876.1, EU789759.1, KU290557.1, KU290905.1, KU290462.1, KU290939.1, KF661086.1, KU290550.1, AB499816.1
# NOTE: Following sequences are identical: EF056448.1, EF056419.1
# NOTE: Following sequences are identical: DQ673917.1, KM820833.1, DQ673908.1
# NOTE: Following sequences are identical: KU290680.1, KU290717.1, KU290831.1, KU290711.1
# NOTE: Following sequences are identical: AB211429.1, AB210267.2
# NOTE: Following sequences are identical: AY962031.1, AY962030.1
# NOTE: Following sequences are identical: AP013079.1, KC202962.1
# NOTE: Following sequences are identical: KM009113.1, KM009112.1, AY172581.1, KM820836.1
# NOTE: Following sequences are identical: AY245607.1, JN003394.1
# NOTE: Following sequences are identical: KP202275.1, KP202273.1, Y08503.1
# NOTE: Following sequences are identical: HM623877.1, HM623881.1
# NOTE: Following sequences are identical: AJ001562.1, X84385.1
# NOTE: Following sequences are identical: KC572849.1, KC572792.1, KC572832.1, KC572745.1, KC572846.1, KC572715.1, KC572735.1, KC572789.1, KC572710.1, KC572712.1, KC572759.1, KC572807.1, KC572747.1, KC572756.1, KC572720.1, KC572817.1, KC572785.1, KC572726.1, KC572718.1, KC572711.1
# NOTE: Following sequences are identical: FM165432.1, AJ630114.1
# NOTE: Following sequences are identical: KJ789952.1, EF545592.1
# NOTE: Following sequences are identical: AY027831.1, AY027827.1
# NOTE: Following sequences are identical: JN415740.1, JN415741.1
# NOTE: Following sequences are identical: GU174594.1, KU963302.1, NC_001602.1
# NOTE: Following sequences are identical: KP205314.1, KP205310.1, KP205309.1, KP205285.1, KP205318.1, KP205313.1, KP205316.1
# NOTE: Following sequences are identical: AJ311131.1, AJ311126.1
# NOTE: Following sequences are identical: LN997430.1, KC776700.1, KC776697.1, KC776708.1, KC776712.1, KC776710.1, KC776713.1
# NOTE: Following sequences are identical: AF091699.1, JQ622004.1, KF938320.1, KF302448.1, HE577848.1, AY858379.1, KF938350.1, KF938325.1, KP998470.1, KF938321.1
# NOTE: Following sequences are identical: KR180348.1, KR180337.1, GU187175.1, GU187187.1, KF418378.1, HQ405754.1, GU187176.1, HQ405752.3, KR180336.1, GU187216.1, KF164610.1, KF418375.1, KF418377.1
# NOTE: Following sequences are identical: JQ287752.1, JQ287756.1, JQ287754.1
# NOTE: Following sequences are identical: AY962041.1, AY962024.1, AY962036.1
#
# NOTE: Found 510 sequence duplicates
# ====> Building a multifurcating tree from taxonomy with 1080 seqs ...
#
# Processed nodes:  1000 , added:  999 , skipped:  1
# Total nodes in resulting tree: 1080
# =====> Building the reference alignment ...
#
# ======> Saving the outgroup for later re-rooting ...
#
# Outgroup for rooting was saved to: /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S_outgr.tre, outgroup size: 4
# =======> Resolving multifurcation: choosing the best topology from 1 independent RAxML runs ...
#
#
# Reducing the alignment:
#
# /home/working/Reference_Alignment/Mammals/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106 -T 5 -f c -s /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S_matrix.afa --no-dup-check -m GTRCAT -n reduce --verbose -p 13332
#
#
# Constrained ML inference:
#
# /home/working/Reference_Alignment/Mammals/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106 -T 5 -s /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S_matrix.afa -g /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S_mfu.tre --no-seq-check -N 1 -m GTRCAT -n mfresolv_12S --verbose -p 326
#
#
# CAT-based logLH of the reference tree: -10929.585844
#
# ========> Calling RAxML-EPA to obtain branch labels ...
#
# /home/working/Reference_Alignment/Mammals/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106 -T 5 -s /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S_lblq.fa -t /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S_bfu.tre --no-seq-check -f y --epa-accumulated-threshold 0.999 -G 0.462962962963 -R /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S.opt -m GTRCAT -n epalbl_12S --verbose -p 26407
#
# =========> Post-processing the EPA tree (re-rooting, taxonomic labeling etc.) ...
#
#
# ==========> Checking branch labels ...
# shared rank names before training: set(['Eukaryota', 'Chordata'])
# shared rank names after  training: set(['Eukaryota', 'unknown', 'Chordata'])
#
# ==========> Saving the reference JSON file: ./12S.refjson
#
# Calculating the speciation rate...
#
# Writing down the reference file...
#
# *** STEP 2: Searching for mislabels ***
#
# Running the leave-one-sequence-out test...
#
# /home/working/Reference_Alignment/Mammals/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106 -T 5 -s /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S.refaln -t /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/ref_12S.tre --no-seq-check -f O --epa-accumulated-threshold 0.999 -G 0.462962962963 -R /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S.opt -m GTRCAT -n l1out_seq_12S --verbose -p 13332
#
# Leave-one-out test identified 35 suspicious sequences; running final EPA test to check them...
#
# /home/working/Reference_Alignment/Mammals/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106 -T 5 -s /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/12S.refaln -t /home/working/Reference_Alignment/Mammals/SATIVA/sativa/tmp/12S_1485190715106/final_ref_12S.tre --no-seq-check -f v --epa-accumulated-threshold 0.999 -G 0.462962962963 -m GTRCAT -n final_epa_12S --verbose -p 326
#
# HM637771.1	Class	Aves	Mammalia	0.995	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Gallus;Gallus gallus	Eukaryota;Chordata;Mammalia;Perissodactyla;Equidae;Equus;Equus caballus	0.999;0.999;0.995;0.184;0.184;0.184;0.184
#
# KF471518.1	Class	Aves	Mammalia	0.991	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Gallus;Gallus gallus	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	0.999;0.999;0.991;0.418;0.181;0.176;0.176
#
# KF471523.1	Class	Aves	Mammalia	0.951	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Gallus;Gallus gallus	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries	1.000;1.000;0.951;0.367;0.216;0.175;0.175
#
# KF484729.1	Class	Aves	Mammalia	0.946	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Gallus;Gallus gallus	Eukaryota;Chordata;Mammalia;Carnivora;Mustelidae;Martes;Martes martes	1.000;1.000;0.946;0.425;0.362;0.100;0.100
#
# M13046.1	Class	Amphibia	Mammalia	0.776	Eukaryota;Chordata;Amphibia;Anura;Pipidae;Xenopus;Xenopus laevis	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	0.999;0.999;0.776;0.351;0.260;0.246;0.246
#
# JQ287755.1	Order	Rodentia	Insectivora	0.898	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Insectivora;Talpidae;Talpa;Talpa europaea	0.999;0.999;0.999;0.898;0.871;0.871;0.871
#
# JQ287761.1	Order	Rodentia	unknown	0.319	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Mus;Mus musculus	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries	0.999;0.999;0.999;0.319;0.307;0.196;0.196
#
# AF320512.1	Order	Cetacea	Carnivora	0.275	Eukaryota;Chordata;Mammalia;Cetacea;Physeteridae;Physeter;Physeter catodon	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	0.999;0.999;0.951;0.275;0.258;0.250;0.250
#
# FM165432.1	Order	Perissodactyla	Carnivora	0.254	Eukaryota;Chordata;Mammalia;Perissodactyla;Equidae;Equus;Equus caballus	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	1.000;1.000;0.971;0.254;0.183;0.180;0.180
#
# AY830134.1	Order	unknown	Carnivora	0.254	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Bos;Bos taurus	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	1.000;1.000;0.971;0.254;0.182;0.179;0.179
#
# AJ630114.1	Order	unknown	Carnivora	0.254	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Bos;Bos taurus	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	1.000;1.000;0.971;0.254;0.183;0.180;0.180
#
# AJ554063.1	Family	Phocoenidae	Delphinidae	0.901	Eukaryota;Chordata;Mammalia;Cetacea;Phocoenidae;Phocoena;Phocoena phocoena	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae	0.999;0.999;0.999;0.999;0.901
#
# JQ287757.1	Family	Muridae	Cricetidae	0.831	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Rodentia;Cricetidae;Myodes;Myodes glareolus	0.999;0.999;0.999;0.977;0.831;0.773;0.773
#
# HM623883.1	Family	Bovidae	Cervidae	0.505	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Capra;Capra hircus	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Capreolus;Capreolus capreolus	0.999;0.999;0.999;0.998;0.505;0.456;0.456
#
# AB018586.1	Genus	Stenella	Tursiops	0.980	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Stenella;Stenella coeruleoalba	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Tursiops;Tursiops truncatus	0.999;0.999;0.999;0.999;0.999;0.980;0.980
#
# EU685091.1	Genus	Delphinus	Tursiops	0.980	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Delphinus;Delphinus delphis	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Tursiops;Tursiops truncatus	0.999;0.999;0.999;0.999;0.999;0.980;0.980
#
# U13083.1	Genus	Delphinus	Tursiops	0.979	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Delphinus;Delphinus delphis	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Tursiops;Tursiops truncatus	0.999;0.999;0.999;0.999;0.999;0.979;0.979
#
# Y08208.1	Genus	Hydropotes	Rangifer	0.961	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Hydropotes;Hydropotes inermis	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Rangifer;Rangifer tarandus	1.000;1.000;1.000;1.000;1.000;0.961;0.961
#
# HM623877.1	Genus	Capra	Ovis	0.632	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Capra;Capra hircus	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries	0.999;0.999;0.999;0.999;0.999;0.632;0.632
#
# DQ867007.1	Genus	Capra	Ovis	0.632	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Capra;Capra hircus	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries	0.999;0.999;0.999;0.999;0.999;0.632;0.632
#
# JQ287756.1	Genus	Rattus	Mus	0.553	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Mus;Mus musculus	0.999;0.999;0.999;0.999;0.864;0.553;0.553
#
# JQ287754.1	Genus	Rattus	Mus	0.553	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Mus;Mus musculus	0.999;0.999;0.999;0.999;0.864;0.553;0.553
#
# JQ287752.1	Genus	Rattus	Mus	0.553	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Mus;Mus musculus	0.999;0.999;0.999;0.999;0.864;0.553;0.553
#
# KF111725.1	Genus	Eptesicus	Vespertilio	0.510	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Eptesicus;Eptesicus serotinus	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Vespertilio;Vespertilio murinus	1.000;1.000;1.000;1.000;1.000;0.510;0.510
#
# D34627.1	Genus	Cervus	Capreolus	0.318	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Cervus;Cervus nippon	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Capreolus;Capreolus capreolus	0.999;0.999;0.999;0.999;0.993;0.318;0.318
#
# JF339973.1	Genus	Globicephala	Tursiops	0.268	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Globicephala;Globicephala melas	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Tursiops;Tursiops truncatus	0.999;0.999;0.999;0.664;0.605;0.268;0.268
#
# NC_001700.1	Species	Felis catus	Felis silvestris	0.930	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis catus	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis silvestris	1.000;1.000;1.000;1.000;0.930;0.930;0.930
#
# Y08503.1	Species	Felis catus	Felis silvestris	0.930	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis catus	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis silvestris	1.000;1.000;1.000;1.000;0.930;0.930;0.930
#
# HQ529667.1	Species	Myotis brandtii	Myotis lucifugus	0.611	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis brandtii	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis lucifugus	0.999;0.999;0.999;0.999;0.997;0.987;0.611
#
# HQ529670.1	Species	Myotis brandtii	Myotis lucifugus	0.611	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis brandtii	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis lucifugus	0.999;0.999;0.999;0.999;0.997;0.987;0.611
#
# HQ529663.1	Species	Myotis brandtii	Myotis lucifugus	0.611	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis brandtii	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis lucifugus	0.999;0.999;0.999;0.999;0.997;0.987;0.611
#
# KM224283.1	Species	Felis catus	Felis silvestris	0.594	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis catus	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis silvestris	1.000;1.000;1.000;1.000;0.594;0.594;0.594
#
# AY495467.1	Species	Eptesicus serotinus	Eptesicus fuscus	0.516	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Eptesicus;Eptesicus serotinus	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Eptesicus;Eptesicus fuscus	1.000;1.000;1.000;1.000;1.000;0.516;0.516
#
# KP142702.1	Species	Cervus elaphus	Cervus nippon	0.441	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Cervus;Cervus elaphus	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Cervus;Cervus nippon	0.999;0.999;0.999;0.999;0.988;0.509;0.441
#
# Mislabeled sequences by rank:
# Class       :	5
# Order       :	6
# Family      :	3
# Genus       :	12
# Species     :	8
#
# Total mislabels: 34 / 3.15 %
#
# Results were saved to: /home/working/Reference_Alignment/Mammals/SATIVA/12S.mis
# Execution log was saved to: /home/working/Reference_Alignment/Mammals/SATIVA/12S.log
#
# Analysis completed successfully, elapsed time: 433 seconds (151s reftree, 282s leave-one-out)

# %% [markdown]
# SATIVA (among other things) writes a report to a text file.

# %%
# !cat 12S.mis
# Out:
# ;WARNING: The revised taxon name suggested here is not necessarily the one that has priority in nomenclature.
# ;Our suggestion should only be taken as indicative of an affiliation to the same group, whose correct name must be determined
# ;in an additional step according to the specific rules of nomenclature that apply to the studied organisms.
# ;
# ;SeqID	MislabeledLevel	OriginalLabel	ProposedLabel	Confidence	OriginalTaxonomyPath	ProposedTaxonomyPath	PerRankConfidence
# HM637771.1	Class	Aves	Mammalia	0.995	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Gallus;Gallus gallus	Eukaryota;Chordata;Mammalia;Perissodactyla;Equidae;Equus;Equus caballus	0.999;0.999;0.995;0.184;0.184;0.184;0.184
# KF471518.1	Class	Aves	Mammalia	0.991	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Gallus;Gallus gallus	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	0.999;0.999;0.991;0.418;0.181;0.176;0.176
# KF471523.1	Class	Aves	Mammalia	0.951	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Gallus;Gallus gallus	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries	1.000;1.000;0.951;0.367;0.216;0.175;0.175
# KF484729.1	Class	Aves	Mammalia	0.946	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Gallus;Gallus gallus	Eukaryota;Chordata;Mammalia;Carnivora;Mustelidae;Martes;Martes martes	1.000;1.000;0.946;0.425;0.362;0.100;0.100
# M13046.1	Class	Amphibia	Mammalia	0.776	Eukaryota;Chordata;Amphibia;Anura;Pipidae;Xenopus;Xenopus laevis	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	0.999;0.999;0.776;0.351;0.260;0.246;0.246
# JQ287755.1	Order	Rodentia	Insectivora	0.898	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Insectivora;Talpidae;Talpa;Talpa europaea	0.999;0.999;0.999;0.898;0.871;0.871;0.871
# JQ287761.1	Order	Rodentia	unknown	0.319	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Mus;Mus musculus	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries	0.999;0.999;0.999;0.319;0.307;0.196;0.196
# AF320512.1	Order	Cetacea	Carnivora	0.275	Eukaryota;Chordata;Mammalia;Cetacea;Physeteridae;Physeter;Physeter catodon	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	0.999;0.999;0.951;0.275;0.258;0.250;0.250
# FM165432.1	Order	Perissodactyla	Carnivora	0.254	Eukaryota;Chordata;Mammalia;Perissodactyla;Equidae;Equus;Equus caballus	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	1.000;1.000;0.971;0.254;0.183;0.180;0.180
# AY830134.1	Order	unknown	Carnivora	0.254	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Bos;Bos taurus	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	1.000;1.000;0.971;0.254;0.182;0.179;0.179
# AJ630114.1	Order	unknown	Carnivora	0.254	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Bos;Bos taurus	Eukaryota;Chordata;Mammalia;Carnivora;Canidae;Canis;Canis lupus	1.000;1.000;0.971;0.254;0.183;0.180;0.180
# AJ554063.1	Family	Phocoenidae	Delphinidae	0.901	Eukaryota;Chordata;Mammalia;Cetacea;Phocoenidae;Phocoena;Phocoena phocoena	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae	0.999;0.999;0.999;0.999;0.901
# JQ287757.1	Family	Muridae	Cricetidae	0.831	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Rodentia;Cricetidae;Myodes;Myodes glareolus	0.999;0.999;0.999;0.977;0.831;0.773;0.773
# HM623883.1	Family	Bovidae	Cervidae	0.505	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Capra;Capra hircus	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Capreolus;Capreolus capreolus	0.999;0.999;0.999;0.998;0.505;0.456;0.456
# AB018586.1	Genus	Stenella	Tursiops	0.980	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Stenella;Stenella coeruleoalba	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Tursiops;Tursiops truncatus	0.999;0.999;0.999;0.999;0.999;0.980;0.980
# EU685091.1	Genus	Delphinus	Tursiops	0.980	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Delphinus;Delphinus delphis	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Tursiops;Tursiops truncatus	0.999;0.999;0.999;0.999;0.999;0.980;0.980
# U13083.1	Genus	Delphinus	Tursiops	0.979	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Delphinus;Delphinus delphis	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Tursiops;Tursiops truncatus	0.999;0.999;0.999;0.999;0.999;0.979;0.979
# Y08208.1	Genus	Hydropotes	Rangifer	0.961	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Hydropotes;Hydropotes inermis	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Rangifer;Rangifer tarandus	1.000;1.000;1.000;1.000;1.000;0.961;0.961
# HM623877.1	Genus	Capra	Ovis	0.632	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Capra;Capra hircus	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries	0.999;0.999;0.999;0.999;0.999;0.632;0.632
# DQ867007.1	Genus	Capra	Ovis	0.632	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Capra;Capra hircus	Eukaryota;Chordata;Mammalia;unknown;Bovidae;Ovis;Ovis aries	0.999;0.999;0.999;0.999;0.999;0.632;0.632
# JQ287756.1	Genus	Rattus	Mus	0.553	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Mus;Mus musculus	0.999;0.999;0.999;0.999;0.864;0.553;0.553
# JQ287754.1	Genus	Rattus	Mus	0.553	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Mus;Mus musculus	0.999;0.999;0.999;0.999;0.864;0.553;0.553
# JQ287752.1	Genus	Rattus	Mus	0.553	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Rattus;Rattus rattus	Eukaryota;Chordata;Mammalia;Rodentia;Muridae;Mus;Mus musculus	0.999;0.999;0.999;0.999;0.864;0.553;0.553
# KF111725.1	Genus	Eptesicus	Vespertilio	0.510	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Eptesicus;Eptesicus serotinus	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Vespertilio;Vespertilio murinus	1.000;1.000;1.000;1.000;1.000;0.510;0.510
# D34627.1	Genus	Cervus	Capreolus	0.318	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Cervus;Cervus nippon	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Capreolus;Capreolus capreolus	0.999;0.999;0.999;0.999;0.993;0.318;0.318
# JF339973.1	Genus	Globicephala	Tursiops	0.268	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Globicephala;Globicephala melas	Eukaryota;Chordata;Mammalia;Cetacea;Delphinidae;Tursiops;Tursiops truncatus	0.999;0.999;0.999;0.664;0.605;0.268;0.268
# NC_001700.1	Species	Felis catus	Felis silvestris	0.930	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis catus	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis silvestris	1.000;1.000;1.000;1.000;0.930;0.930;0.930
# Y08503.1	Species	Felis catus	Felis silvestris	0.930	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis catus	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis silvestris	1.000;1.000;1.000;1.000;0.930;0.930;0.930
# HQ529667.1	Species	Myotis brandtii	Myotis lucifugus	0.611	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis brandtii	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis lucifugus	0.999;0.999;0.999;0.999;0.997;0.987;0.611
# HQ529670.1	Species	Myotis brandtii	Myotis lucifugus	0.611	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis brandtii	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis lucifugus	0.999;0.999;0.999;0.999;0.997;0.987;0.611
# HQ529663.1	Species	Myotis brandtii	Myotis lucifugus	0.611	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis brandtii	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Myotis;Myotis lucifugus	0.999;0.999;0.999;0.999;0.997;0.987;0.611
# KM224283.1	Species	Felis catus	Felis silvestris	0.594	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis catus	Eukaryota;Chordata;Mammalia;Carnivora;Felidae;Felis;Felis silvestris	1.000;1.000;1.000;1.000;0.594;0.594;0.594
# AY495467.1	Species	Eptesicus serotinus	Eptesicus fuscus	0.516	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Eptesicus;Eptesicus serotinus	Eukaryota;Chordata;Mammalia;Chiroptera;Vespertilionidae;Eptesicus;Eptesicus fuscus	1.000;1.000;1.000;1.000;1.000;0.516;0.516
# KP142702.1	Species	Cervus elaphus	Cervus nippon	0.441	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Cervus;Cervus elaphus	Eukaryota;Chordata;Mammalia;unknown;Cervidae;Cervus;Cervus nippon	0.999;0.999;0.999;0.999;0.988;0.509;0.441
