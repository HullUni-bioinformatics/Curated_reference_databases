# %% [markdown]
# Prepare input files.
#
# The ailgnment has been produced using Reprophylo (see notebook). We'll just cleanup the sequence headers and create a local copy.

# %%
# !cat ../fetch_clean_align_tree/trimmed_bird_align_ALL.phy | sed 's/_f[0-9] / /' > alignment.phy

# %% [markdown]
# The tax file has been generated from a Genbank file using this notebook.

# %%
# !head tax_for_SATIVA.tax
# Out:
# AP009190.1	Eukaryota;Chordata;Aves;Gaviiformes;Gaviidae;Gavia;Gavia pacifica
# KC545397.1	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Anthus;Anthus novaeseelandiae
# HQ890328.1	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Anser;Anser fabalis
# AY164514.1	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Anser;Anser fabalis
# AM902520.1	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Tetrao;Tetrao urogallus
# FN675567.1	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Tetrao;Tetrao urogallus
# FN675573.1	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Tetrao;Tetrao urogallus
# FN675574.1	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Tetrao;Tetrao urogallus
# AF230158.1	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Tetrao;Tetrao urogallus
# AY465753.1	Eukaryota;Chordata;Aves;Pelecaniformes;Threskiornithidae;Platalea;Platalea leucorodia

# %% [markdown]
# Let's now run SATIVA.

# %%
# !./sativa/sativa.py -s alignment.phy -t tax_for_SATIVA.tax -x zoo -n 12S -o ./ -T 5 -v
# Out:
# SATIVA v0.9-55-g0cbb090, released on 2016-06-28. Last version: https://github.com/amkozlov/sativa
# By A.Kozlov and J.Zhang, the Exelixis Lab. Based on RAxML 8.2.3 by A.Stamatakis.
#
# SATIVA was called as follows:
#
# ./sativa/sativa.py -s alignment.phy -t tax_for_SATIVA.tax -x zoo -n 12S -o ./ -T 5 -v
#
# Mislabels search is running with the following parameters:
#  Alignment:                        alignment.phy
#  Taxonomy:                         tax_for_SATIVA.tax
#  Output directory:                 /home/working/Reference_Alignment/Birds/SATIVA
#  Job name / output files prefix:   12S
#  Model of rate heterogeneity:      AUTO
#  Confidence cut-off:               0.000000
#  Number of threads:                5
#
# *** STEP 1: Building the reference tree using provided alignment and taxonomic annotations ***
#
# => Loading taxonomy from file: tax_for_SATIVA.tax ...
#
# ==> Loading reference alignment from file: alignment.phy ...
#
# Guessing input format: not fasta
# Guessing input format: not phylip_relaxed
# ===> Validating taxonomy and alignment ...
#
# NOTE: Following sequences are identical: AB042354.1, AY635096.1
# NOTE: Following sequences are identical: JQ422391.1, JQ422386.1
# NOTE: Following sequences are identical: AY164525.1, KF312717.1
# NOTE: Following sequences are identical: AM902517.1, FN675555.1
#
# NOTE: Found 4 sequence duplicates
# ====> Building a multifurcating tree from taxonomy with 675 seqs ...
#
# Total nodes in resulting tree: 675
# =====> Building the reference alignment ...
#
# ======> Saving the outgroup for later re-rooting ...
#
# Outgroup for rooting was saved to: /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S_outgr.tre, outgroup size: 13
# =======> Resolving multifurcation: choosing the best topology from 1 independent RAxML runs ...
#
#
# Reducing the alignment:
#
# /home/working/Reference_Alignment/Birds/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003 -T 5 -f c -s /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S_matrix.afa --no-dup-check -m GTRCAT -n reduce --verbose -p 13332
#
#
# Constrained ML inference:
#
# /home/working/Reference_Alignment/Birds/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003 -T 5 -s /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S_matrix.afa -g /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S_mfu.tre --no-seq-check -N 1 -m GTRCAT -n mfresolv_12S --verbose -p 326
#
#
# CAT-based logLH of the reference tree: -66135.561811
#
# ========> Calling RAxML-EPA to obtain branch labels ...
#
# /home/working/Reference_Alignment/Birds/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003 -T 5 -s /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S_lblq.fa -t /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S_bfu.tre --no-seq-check -f y --epa-accumulated-threshold 0.999 -R /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S.opt -m GTRCAT -n epalbl_12S --verbose -p 26407
#
# =========> Post-processing the EPA tree (re-rooting, taxonomic labeling etc.) ...
#
#
# ==========> Checking branch labels ...
# shared rank names before training: set(['Eukaryota', 'Chordata'])
# shared rank names after  training: set(['Eukaryota', 'unknown', '-', 'Chordata'])
#
# ==========> Saving the reference JSON file: ./12S.refjson
#
# Calculating the speciation rate...
#
# Writing down the reference file...
#
# *** STEP 2: Searching for mislabels ***
#
# Running the leave-one-sequence-out test...
#
# /home/working/Reference_Alignment/Birds/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003 -T 5 -s /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S.refaln -t /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/ref_12S.tre --no-seq-check -f O --epa-accumulated-threshold 0.999 -R /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S.opt -m GTRCAT -n l1out_seq_12S --verbose -p 13332
#
# Leave-one-out test identified 76 suspicious sequences; running final EPA test to check them...
#
# /home/working/Reference_Alignment/Birds/SATIVA/sativa/raxml//run_raxml.sh -w /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003 -T 5 -s /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/12S.refaln -t /home/working/Reference_Alignment/Birds/SATIVA/sativa/tmp/12S_1477669568003/final_ref_12S.tre --no-seq-check -f v --epa-accumulated-threshold 0.999 -m GTRCAT -n final_epa_12S --verbose -p 326
#
# AF173564.1	Order	Gruiformes	Charadriiformes	0.999	Eukaryota;Chordata;Aves;Gruiformes;Gruidae;Grus;Grus canadensis	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae	0.999;0.999;0.999;0.999;0.515
#
# KP171706.1	Order	Anseriformes	Columbiformes	0.999	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Anas;Anas platyrhynchos	Eukaryota;Chordata;Aves;Columbiformes;Columbidae;Columba;Columba livia	0.999;0.999;0.999;0.999;0.999;0.606;0.487
#
# AF407431.1	Order	Coraciiformes	Charadriiformes	0.919	Eukaryota;Chordata;Aves;Coraciiformes	Eukaryota;Chordata;Aves;Charadriiformes	0.999;0.999;0.999;0.919
#
# EU167070.1	Order	Podicipediformes	Piciformes	0.510	Eukaryota;Chordata;Aves;Podicipediformes;Podicipedidae;Podilymbus;Podilymbus podiceps	Eukaryota;Chordata;Aves;Piciformes;Picidae	1.000;1.000;1.000;0.510;0.510
#
# KR215630.1	Order	Pelecaniformes	Cuculiformes	0.492	Eukaryota;Chordata;Aves;Pelecaniformes	Eukaryota;Chordata;Aves;Cuculiformes;Coccyzidae;Coccyzus	0.999;0.999;0.999;0.492;0.492;0.492
#
# FR873680.1	Order	Columbiformes	Passeriformes	0.257	Eukaryota;Chordata;Aves;Columbiformes;Columbidae;Columba;Columba livia	Eukaryota;Chordata;Aves;Passeriformes	0.999;0.999;0.966;0.257
#
# AF407087.1	Family	Passerellidae	Fringillidae	1.000	Eukaryota;Chordata;Aves;Passeriformes;Passerellidae	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	1.000;1.000;1.000;1.000;1.000
#
# AF173599.1	Family	Turdidae	Fringillidae	1.000	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Turdus;Turdus migratorius	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	1.000;1.000;1.000;1.000;1.000
#
# KU158188.1	Family	Laridae	Alcidae	1.000	Eukaryota;Chordata;Aves;Charadriiformes;Laridae	Eukaryota;Chordata;Aves;Charadriiformes;Alcidae	1.000;1.000;1.000;1.000;1.000
#
# AF447226.1	Family	Icteridae	Fringillidae	1.000	Eukaryota;Chordata;Aves;Passeriformes;Icteridae	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	1.000;1.000;1.000;1.000;1.000
#
# KF781333.1	Family	Sturnidae	Fringillidae	0.999	Eukaryota;Chordata;Aves;Passeriformes;Sturnidae;Sturnus;Sturnus vulgaris	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.999
#
# HQ852942.1	Family	Phylloscopidae	Turdidae	0.999	Eukaryota;Chordata;Aves;Passeriformes;Phylloscopidae;Phylloscopus;Phylloscopus schwarzi	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Turdus;Turdus naumanni	0.999;0.999;0.999;0.999;0.999;0.999;0.509
#
# HQ852945.1	Family	Sylviidae	Fringillidae	0.999	Eukaryota;Chordata;Aves;Passeriformes;Sylviidae;Locustella	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Schoeniclus;Schoeniclus spodocephala	0.999;0.999;0.999;0.999;0.999;0.951;0.862
#
# HQ852941.1	Family	Phylloscopidae	Muscicapidae	0.994	Eukaryota;Chordata;Aves;Passeriformes;Phylloscopidae;Abrornis;Abrornis proregulus	Eukaryota;Chordata;Aves;Passeriformes;Muscicapidae	1.000;1.000;1.000;1.000;0.994
#
# EF027300.1	Family	Certhiidae	Corvidae	0.952	Eukaryota;Chordata;Aves;Passeriformes;Certhiidae	Eukaryota;Chordata;Aves;Passeriformes;Corvidae;Pica;Pica pica	0.999;0.999;0.999;0.997;0.952;0.644;0.644
#
# KF997863.1	Family	Muscicapidae	Turdidae	0.945	Eukaryota;Chordata;Aves;Passeriformes;Muscicapidae;Phoenicurus;Phoenicurus auroreus	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Luscinia;Luscinia cyanura	0.999;0.999;0.999;0.999;0.945;0.482;0.482
#
# HQ852931.1	Family	Muscicapidae	Turdidae	0.939	Eukaryota;Chordata;Aves;Passeriformes;Muscicapidae;Ficedula	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Luscinia;Luscinia cyanura	1.000;1.000;1.000;1.000;0.939;0.472;0.472
#
# KC545397.1	Family	Motacillidae	Passeridae	0.926	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae	Eukaryota;Chordata;Aves;Passeriformes;Passeridae	0.999;0.999;0.999;0.999;0.926
#
# KM078790.1	Family	Fringillidae	Passeridae	0.875	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Carduelis;Carduelis carduelis	Eukaryota;Chordata;Aves;Passeriformes;Passeridae;Passer;Passer montanus	0.999;0.999;0.999;0.999;0.875;0.759;0.424
#
# AY259407.1	Family	Motacillidae	Fringillidae	0.601	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.601
#
# AY259421.1	Family	Motacillidae	Fringillidae	0.601	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.601
#
# AY259399.1	Family	Motacillidae	Fringillidae	0.601	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.601
#
# AY259424.1	Family	Motacillidae	Fringillidae	0.592	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.998;0.592
#
# AY259411.1	Family	Motacillidae	Fringillidae	0.588	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.588
#
# AY259404.1	Family	Motacillidae	Fringillidae	0.588	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.588
#
# AY259390.1	Family	Motacillidae	Fringillidae	0.580	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla cinerea	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.995;0.580
#
# AF447237.1	Family	Icteridae	Passerellidae	0.508	Eukaryota;Chordata;Aves;Passeriformes;Icteridae	Eukaryota;Chordata;Aves;Passeriformes;Passerellidae;Pipilo;Pipilo erythrophthalmus	0.999;0.999;0.999;0.999;0.508;0.508;0.508
#
# EF027311.1	Family	Paridae	Turdidae	0.406	Eukaryota;Chordata;Aves;Passeriformes;Paridae;Periparus;Periparus ater	Eukaryota;Chordata;Aves;Passeriformes;Turdidae	0.999;0.999;0.999;0.998;0.406
#
# KJ710708.1	Subtribe	Aythya ferina	Aythya fuligula	0.510	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Aythya;Aythya ferina	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Aythya;Aythya fuligula	1.000;1.000;1.000;1.000;1.000;1.000;0.510
#
# KC407232.1	Genus	Emberiza	Schoeniclus	1.000	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Emberiza;Emberiza pusilla	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Schoeniclus	1.000;1.000;1.000;1.000;1.000;1.000
#
# EF373090.2	Genus	Limnodromus	Phalaropus	1.000	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Limnodromus;Limnodromus scolopaceus	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Phalaropus;Phalaropus tricolor	1.000;1.000;1.000;1.000;1.000;1.000;0.510
#
# HQ852943.1	Genus	Schoeniclus	Emberiza	1.000	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Schoeniclus;Schoeniclus aureolus	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Emberiza	1.000;1.000;1.000;1.000;1.000;1.000
#
# GU390886.1	Genus	Aquila	Buteo	0.999	Eukaryota;Chordata;Aves;Falconiformes;Accipitridae;Aquila	Eukaryota;Chordata;Aves;Falconiformes;Accipitridae;Buteo;Buteo buteo	0.999;0.999;0.999;0.999;0.999;0.999;0.964
#
# AY635106.1	Genus	Phylloscopus	Abrornis	0.955	Eukaryota;Chordata;Aves;Passeriformes;Phylloscopidae;Phylloscopus;Phylloscopus schwarzi	Eukaryota;Chordata;Aves;Passeriformes;Phylloscopidae;Abrornis	0.999;0.999;0.999;0.999;0.999;0.955
#
# L22477.1	Genus	Anas	Mareca	0.882	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Anas;Anas platyrhynchos	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Mareca	0.999;0.999;0.999;0.999;0.999;0.882
#
# DQ832102.1	Genus	Chrysolophus	Phasianus	0.741	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Chrysolophus;Chrysolophus amherstiae	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Phasianus;Phasianus colchicus	0.999;0.999;0.999;0.999;0.999;0.741;0.741
#
# DQ674556.1	Genus	Podilymbus	Podiceps	0.535	Eukaryota;Chordata;Aves;Podicipediformes;Podicipedidae;Podilymbus;Podilymbus podiceps	Eukaryota;Chordata;Aves;Podicipediformes;Podicipedidae;Podiceps	1.000;1.000;1.000;0.535;0.535;0.535
#
# FJ752433.1	Genus	Chrysolophus	Phasianus	0.520	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Chrysolophus;Chrysolophus pictus	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Phasianus;Phasianus colchicus	1.000;1.000;1.000;1.000;1.000;0.520;0.520
#
# AF173585.1	Genus	Columba	Zenaida	0.510	Eukaryota;Chordata;Aves;Columbiformes;Columbidae;Columba;Columba livia	Eukaryota;Chordata;Aves;Columbiformes;Columbidae;Zenaida;Zenaida macroura	1.000;1.000;1.000;1.000;1.000;0.510;0.510
#
# FJ752434.1	Genus	Chrysolophus	Phasianus	0.510	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Chrysolophus;Chrysolophus amherstiae	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Phasianus;Phasianus colchicus	1.000;1.000;1.000;1.000;1.000;0.510;0.510
#
# EF373082.2	Genus	Gallinago	Limnodromus	0.509	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago gallinago	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Limnodromus;Limnodromus griseus	0.999;0.999;0.999;0.999;0.999;0.509;0.509
#
# EU154482.1	Genus	Catharus	Ixoreus	0.494	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Catharus	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Ixoreus;Ixoreus naevius	0.999;0.999;0.999;0.999;0.999;0.494;0.494
#
# AY631338.1	Genus	Sterna	Thalasseus	0.493	Eukaryota;Chordata;Aves;Charadriiformes;Laridae;Sterna	Eukaryota;Chordata;Aves;Charadriiformes;Laridae;Thalasseus;Thalasseus maximus	1.000;1.000;1.000;1.000;1.000;0.493;0.493
#
# AY164523.1	Species	Cygnus cygnus	Cygnus columbianus	1.000	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Cygnus;Cygnus cygnus	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Cygnus;Cygnus columbianus	1.000;1.000;1.000;1.000;1.000;1.000;1.000
#
# FJ603663.1	Species	Gallinago delicata	Gallinago gallinago	0.996	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago delicata	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago gallinago	1.000;1.000;1.000;1.000;1.000;1.000;0.996
#
# AM237310.1	Species	Apus apus	Apus pallidus	0.814	Eukaryota;Chordata;Aves;Apodiformes;Apodidae;Apus;Apus apus	Eukaryota;Chordata;Aves;Apodiformes;Apodidae;Apus;Apus pallidus	1.000;1.000;1.000;1.000;1.000;1.000;0.814
#
# AY275847.1	Species	Apus apus	Apus affinis	0.540	Eukaryota;Chordata;Aves;Apodiformes;Apodidae;Apus;Apus apus	Eukaryota;Chordata;Aves;Apodiformes;Apodidae;Apus;Apus affinis	1.000;1.000;1.000;1.000;1.000;0.880;0.540
#
# U83758.1	Species	Asio flammeus	Asio otus	0.510	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Asio;Asio flammeus	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Asio;Asio otus	1.000;1.000;1.000;1.000;1.000;1.000;0.510
#
# AY513589.1	Species	Bubo bubo	Bubo virginianus	0.510	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Bubo;Bubo bubo	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Bubo;Bubo virginianus	1.000;1.000;1.000;1.000;1.000;0.510;0.510
#
# AF173577.1	Species	Gavia immer	Gavia adamsii	0.510	Eukaryota;Chordata;Aves;Gaviiformes;Gaviidae;Gavia;Gavia immer	Eukaryota;Chordata;Aves;Gaviiformes;Gaviidae;Gavia;Gavia adamsii	1.000;1.000;1.000;1.000;1.000;1.000;0.510
#
# AB918148.1	Species	Bubo bubo	Bubo virginianus	0.510	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Bubo;Bubo bubo	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Bubo;Bubo virginianus	1.000;1.000;1.000;1.000;1.000;0.510;0.510
#
# JQ962983.1	Species	Gallinago delicata	Gallinago media	0.510	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago delicata	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago media	1.000;1.000;1.000;1.000;1.000;1.000;0.510
#
# AF230154.1	Species	Lagopus muta	Lagopus lagopus	0.509	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Lagopus;Lagopus muta	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Lagopus;Lagopus lagopus	0.999;0.999;0.999;0.999;0.999;0.999;0.509
#
# Mislabeled sequences by rank:
# Order       :	6
# Family      :	22
# Subtribe    :	1
# Genus       :	14
# Species     :	10
#
# Total mislabels: 53 / 7.85 %
#
# Results were saved to: /home/working/Reference_Alignment/Birds/SATIVA/12S.mis
# Execution log was saved to: /home/working/Reference_Alignment/Birds/SATIVA/12S.log
#
# Analysis completed successfully, elapsed time: 582 seconds (99s reftree, 483s leave-one-out)

# %% [markdown]
# SATIVA (among other things) writes a report to a text file.

# %%
# !cat 12S.mis
# Out:
# ;WARNING: The revised taxon name suggested here is not necessarily the one that has priority in nomenclature.
# ;Our suggestion should only be taken as indicative of an affiliation to the same group, whose correct name must be determined
# ;in an additional step according to the specific rules of nomenclature that apply to the studied organisms.
# ;
# ;SeqID	MislabeledLevel	OriginalLabel	ProposedLabel	Confidence	OriginalTaxonomyPath	ProposedTaxonomyPath	PerRankConfidence
# AF173564.1	Order	Gruiformes	Charadriiformes	0.999	Eukaryota;Chordata;Aves;Gruiformes;Gruidae;Grus;Grus canadensis	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae	0.999;0.999;0.999;0.999;0.515
# KP171706.1	Order	Anseriformes	Columbiformes	0.999	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Anas;Anas platyrhynchos	Eukaryota;Chordata;Aves;Columbiformes;Columbidae;Columba;Columba livia	0.999;0.999;0.999;0.999;0.999;0.606;0.487
# AF407431.1	Order	Coraciiformes	Charadriiformes	0.919	Eukaryota;Chordata;Aves;Coraciiformes	Eukaryota;Chordata;Aves;Charadriiformes	0.999;0.999;0.999;0.919
# EU167070.1	Order	Podicipediformes	Piciformes	0.510	Eukaryota;Chordata;Aves;Podicipediformes;Podicipedidae;Podilymbus;Podilymbus podiceps	Eukaryota;Chordata;Aves;Piciformes;Picidae	1.000;1.000;1.000;0.510;0.510
# KR215630.1	Order	Pelecaniformes	Cuculiformes	0.492	Eukaryota;Chordata;Aves;Pelecaniformes	Eukaryota;Chordata;Aves;Cuculiformes;Coccyzidae;Coccyzus	0.999;0.999;0.999;0.492;0.492;0.492
# FR873680.1	Order	Columbiformes	Passeriformes	0.257	Eukaryota;Chordata;Aves;Columbiformes;Columbidae;Columba;Columba livia	Eukaryota;Chordata;Aves;Passeriformes	0.999;0.999;0.966;0.257
# AF407087.1	Family	Passerellidae	Fringillidae	1.000	Eukaryota;Chordata;Aves;Passeriformes;Passerellidae	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	1.000;1.000;1.000;1.000;1.000
# AF173599.1	Family	Turdidae	Fringillidae	1.000	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Turdus;Turdus migratorius	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	1.000;1.000;1.000;1.000;1.000
# KU158188.1	Family	Laridae	Alcidae	1.000	Eukaryota;Chordata;Aves;Charadriiformes;Laridae	Eukaryota;Chordata;Aves;Charadriiformes;Alcidae	1.000;1.000;1.000;1.000;1.000
# AF447226.1	Family	Icteridae	Fringillidae	1.000	Eukaryota;Chordata;Aves;Passeriformes;Icteridae	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	1.000;1.000;1.000;1.000;1.000
# KF781333.1	Family	Sturnidae	Fringillidae	0.999	Eukaryota;Chordata;Aves;Passeriformes;Sturnidae;Sturnus;Sturnus vulgaris	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.999
# HQ852942.1	Family	Phylloscopidae	Turdidae	0.999	Eukaryota;Chordata;Aves;Passeriformes;Phylloscopidae;Phylloscopus;Phylloscopus schwarzi	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Turdus;Turdus naumanni	0.999;0.999;0.999;0.999;0.999;0.999;0.509
# HQ852945.1	Family	Sylviidae	Fringillidae	0.999	Eukaryota;Chordata;Aves;Passeriformes;Sylviidae;Locustella	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Schoeniclus;Schoeniclus spodocephala	0.999;0.999;0.999;0.999;0.999;0.951;0.862
# HQ852941.1	Family	Phylloscopidae	Muscicapidae	0.994	Eukaryota;Chordata;Aves;Passeriformes;Phylloscopidae;Abrornis;Abrornis proregulus	Eukaryota;Chordata;Aves;Passeriformes;Muscicapidae	1.000;1.000;1.000;1.000;0.994
# EF027300.1	Family	Certhiidae	Corvidae	0.952	Eukaryota;Chordata;Aves;Passeriformes;Certhiidae	Eukaryota;Chordata;Aves;Passeriformes;Corvidae;Pica;Pica pica	0.999;0.999;0.999;0.997;0.952;0.644;0.644
# KF997863.1	Family	Muscicapidae	Turdidae	0.945	Eukaryota;Chordata;Aves;Passeriformes;Muscicapidae;Phoenicurus;Phoenicurus auroreus	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Luscinia;Luscinia cyanura	0.999;0.999;0.999;0.999;0.945;0.482;0.482
# HQ852931.1	Family	Muscicapidae	Turdidae	0.939	Eukaryota;Chordata;Aves;Passeriformes;Muscicapidae;Ficedula	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Luscinia;Luscinia cyanura	1.000;1.000;1.000;1.000;0.939;0.472;0.472
# KC545397.1	Family	Motacillidae	Passeridae	0.926	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae	Eukaryota;Chordata;Aves;Passeriformes;Passeridae	0.999;0.999;0.999;0.999;0.926
# KM078790.1	Family	Fringillidae	Passeridae	0.875	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Carduelis;Carduelis carduelis	Eukaryota;Chordata;Aves;Passeriformes;Passeridae;Passer;Passer montanus	0.999;0.999;0.999;0.999;0.875;0.759;0.424
# AY259407.1	Family	Motacillidae	Fringillidae	0.601	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.601
# AY259421.1	Family	Motacillidae	Fringillidae	0.601	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.601
# AY259399.1	Family	Motacillidae	Fringillidae	0.601	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.601
# AY259424.1	Family	Motacillidae	Fringillidae	0.592	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.998;0.592
# AY259411.1	Family	Motacillidae	Fringillidae	0.588	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.588
# AY259404.1	Family	Motacillidae	Fringillidae	0.588	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla flava	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.999;0.588
# AY259390.1	Family	Motacillidae	Fringillidae	0.580	Eukaryota;Chordata;Aves;Passeriformes;Motacillidae;Motacilla;Motacilla cinerea	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae	0.999;0.999;0.999;0.995;0.580
# AF447237.1	Family	Icteridae	Passerellidae	0.508	Eukaryota;Chordata;Aves;Passeriformes;Icteridae	Eukaryota;Chordata;Aves;Passeriformes;Passerellidae;Pipilo;Pipilo erythrophthalmus	0.999;0.999;0.999;0.999;0.508;0.508;0.508
# EF027311.1	Family	Paridae	Turdidae	0.406	Eukaryota;Chordata;Aves;Passeriformes;Paridae;Periparus;Periparus ater	Eukaryota;Chordata;Aves;Passeriformes;Turdidae	0.999;0.999;0.999;0.998;0.406
# KJ710708.1	Subtribe	Aythya ferina	Aythya fuligula	0.510	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Aythya;Aythya ferina	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Aythya;Aythya fuligula	1.000;1.000;1.000;1.000;1.000;1.000;0.510
# KC407232.1	Genus	Emberiza	Schoeniclus	1.000	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Emberiza;Emberiza pusilla	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Schoeniclus	1.000;1.000;1.000;1.000;1.000;1.000
# EF373090.2	Genus	Limnodromus	Phalaropus	1.000	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Limnodromus;Limnodromus scolopaceus	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Phalaropus;Phalaropus tricolor	1.000;1.000;1.000;1.000;1.000;1.000;0.510
# HQ852943.1	Genus	Schoeniclus	Emberiza	1.000	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Schoeniclus;Schoeniclus aureolus	Eukaryota;Chordata;Aves;Passeriformes;Fringillidae;Emberiza	1.000;1.000;1.000;1.000;1.000;1.000
# GU390886.1	Genus	Aquila	Buteo	0.999	Eukaryota;Chordata;Aves;Falconiformes;Accipitridae;Aquila	Eukaryota;Chordata;Aves;Falconiformes;Accipitridae;Buteo;Buteo buteo	0.999;0.999;0.999;0.999;0.999;0.999;0.964
# AY635106.1	Genus	Phylloscopus	Abrornis	0.955	Eukaryota;Chordata;Aves;Passeriformes;Phylloscopidae;Phylloscopus;Phylloscopus schwarzi	Eukaryota;Chordata;Aves;Passeriformes;Phylloscopidae;Abrornis	0.999;0.999;0.999;0.999;0.999;0.955
# L22477.1	Genus	Anas	Mareca	0.882	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Anas;Anas platyrhynchos	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Mareca	0.999;0.999;0.999;0.999;0.999;0.882
# DQ832102.1	Genus	Chrysolophus	Phasianus	0.741	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Chrysolophus;Chrysolophus amherstiae	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Phasianus;Phasianus colchicus	0.999;0.999;0.999;0.999;0.999;0.741;0.741
# DQ674556.1	Genus	Podilymbus	Podiceps	0.535	Eukaryota;Chordata;Aves;Podicipediformes;Podicipedidae;Podilymbus;Podilymbus podiceps	Eukaryota;Chordata;Aves;Podicipediformes;Podicipedidae;Podiceps	1.000;1.000;1.000;0.535;0.535;0.535
# FJ752433.1	Genus	Chrysolophus	Phasianus	0.520	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Chrysolophus;Chrysolophus pictus	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Phasianus;Phasianus colchicus	1.000;1.000;1.000;1.000;1.000;0.520;0.520
# AF173585.1	Genus	Columba	Zenaida	0.510	Eukaryota;Chordata;Aves;Columbiformes;Columbidae;Columba;Columba livia	Eukaryota;Chordata;Aves;Columbiformes;Columbidae;Zenaida;Zenaida macroura	1.000;1.000;1.000;1.000;1.000;0.510;0.510
# FJ752434.1	Genus	Chrysolophus	Phasianus	0.510	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Chrysolophus;Chrysolophus amherstiae	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Phasianus;Phasianus colchicus	1.000;1.000;1.000;1.000;1.000;0.510;0.510
# EF373082.2	Genus	Gallinago	Limnodromus	0.509	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago gallinago	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Limnodromus;Limnodromus griseus	0.999;0.999;0.999;0.999;0.999;0.509;0.509
# EU154482.1	Genus	Catharus	Ixoreus	0.494	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Catharus	Eukaryota;Chordata;Aves;Passeriformes;Turdidae;Ixoreus;Ixoreus naevius	0.999;0.999;0.999;0.999;0.999;0.494;0.494
# AY631338.1	Genus	Sterna	Thalasseus	0.493	Eukaryota;Chordata;Aves;Charadriiformes;Laridae;Sterna	Eukaryota;Chordata;Aves;Charadriiformes;Laridae;Thalasseus;Thalasseus maximus	1.000;1.000;1.000;1.000;1.000;0.493;0.493
# AY164523.1	Species	Cygnus cygnus	Cygnus columbianus	1.000	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Cygnus;Cygnus cygnus	Eukaryota;Chordata;Aves;Anseriformes;Anatidae;Cygnus;Cygnus columbianus	1.000;1.000;1.000;1.000;1.000;1.000;1.000
# FJ603663.1	Species	Gallinago delicata	Gallinago gallinago	0.996	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago delicata	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago gallinago	1.000;1.000;1.000;1.000;1.000;1.000;0.996
# AM237310.1	Species	Apus apus	Apus pallidus	0.814	Eukaryota;Chordata;Aves;Apodiformes;Apodidae;Apus;Apus apus	Eukaryota;Chordata;Aves;Apodiformes;Apodidae;Apus;Apus pallidus	1.000;1.000;1.000;1.000;1.000;1.000;0.814
# AY275847.1	Species	Apus apus	Apus affinis	0.540	Eukaryota;Chordata;Aves;Apodiformes;Apodidae;Apus;Apus apus	Eukaryota;Chordata;Aves;Apodiformes;Apodidae;Apus;Apus affinis	1.000;1.000;1.000;1.000;1.000;0.880;0.540
# U83758.1	Species	Asio flammeus	Asio otus	0.510	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Asio;Asio flammeus	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Asio;Asio otus	1.000;1.000;1.000;1.000;1.000;1.000;0.510
# AY513589.1	Species	Bubo bubo	Bubo virginianus	0.510	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Bubo;Bubo bubo	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Bubo;Bubo virginianus	1.000;1.000;1.000;1.000;1.000;0.510;0.510
# AF173577.1	Species	Gavia immer	Gavia adamsii	0.510	Eukaryota;Chordata;Aves;Gaviiformes;Gaviidae;Gavia;Gavia immer	Eukaryota;Chordata;Aves;Gaviiformes;Gaviidae;Gavia;Gavia adamsii	1.000;1.000;1.000;1.000;1.000;1.000;0.510
# AB918148.1	Species	Bubo bubo	Bubo virginianus	0.510	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Bubo;Bubo bubo	Eukaryota;Chordata;Aves;Strigiformes;Strigidae;Bubo;Bubo virginianus	1.000;1.000;1.000;1.000;1.000;0.510;0.510
# JQ962983.1	Species	Gallinago delicata	Gallinago media	0.510	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago delicata	Eukaryota;Chordata;Aves;Charadriiformes;Scolopacidae;Gallinago;Gallinago media	1.000;1.000;1.000;1.000;1.000;1.000;0.510
# AF230154.1	Species	Lagopus muta	Lagopus lagopus	0.509	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Lagopus;Lagopus muta	Eukaryota;Chordata;Aves;Galliformes;Phasianidae;Lagopus;Lagopus lagopus	0.999;0.999;0.999;0.999;0.999;0.999;0.509
